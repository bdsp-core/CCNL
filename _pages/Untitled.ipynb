# %%
import pandas as pd
import re

def parse_quotes_md(file_path):
    # Read the markdown file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    
    # Find section headers
    sections = re.findall(r'###\s+(.+)', content)
    
    # Create a pattern to match blockquotes with their attributions
    quote_pattern = re.compile(r'(> "[\s\S]+?")\s*\n>\s*\n> \*\*--_(.+?)_\*\*')
    
    # Find all quotes and their indices
    quotes_attributions_indices = [(match.group(1), match.group(2), match.start())
                                   for match in quote_pattern.finditer(content)]
    
    # Data to create DataFrame
    data = []
    
    # Track the current section index
    current_section = ''
    current_section_index = 0

    # Iterate through each quote and attribution pair with its index
    for quote, attribution, index in quotes_attributions_indices:
        # Find current section based on index
        while current_section_index + 1 < len(sections) and \
              content.find('### ' + sections[current_section_index + 1]) < index:
            current_section_index += 1
        current_section = sections[current_section_index]
        
        # Clean the quote string
        quote = quote.strip('> " ').replace('\n', ' ')
        
        # Append the quote, its attribution, and the current section to the data list
        data.append({'Section': current_section, 'Quote': quote, 'Attribution': attribution})
    
    # Create a DataFrame
    df = pd.DataFrame(data)
    
    # Save to CSV
    df.to_csv('quotes.csv', index=False)
    
    return df

# Parse the markdown and get the DataFrame
file_path = 'quotes.md'
df = parse_quotes_md(file_path)

# Display the DataFrame
print(df)
# Out:
#                              Section  \
# 0                          Academics
# 1                              Faith
# 2                          Suffering
# 3                            Passion
# 4                         Psychology
# 5                            Science
# 6                            Science
# 7                            Science
# 8                            Science
# 9                            Science
# 10                           Science
# 11                           Science
# 12                           Science
# 13                           Science
# 14                           Science
# 15                           Science
# 16                           Science
# 17                          Teaching
# 18                          Teaching
# 19                          Teaching
# 20                          Teaching
# 21                          Teaching
# 22                          Teaching
# 23                        Technology
# 24                             Logic
# 25                             Logic
# 26                             Logic
# 27                             Logic
# 28                             Logic
# 29                              Math
# 30                              Math
# 31                              Math
# 32                              Math
# 33                              Math
# 34                              Math
# 35                              Math
# 36                              Math
# 37                              Math
# 38                              Math
# 39                              Math
# 40                              Math
# 41                              Math
# 42                              Math
# 43                              Math
# 44                              Math
# 45                              Math
# 46                              Math
# 47                              Math
# 48                              Math
# 49                        Math Jokes
# 50                        Math Jokes
# 51                        Math Jokes
# 52                        Philosophy
# 53               Philosophical jokes
# 54                       Probability
# 55  Probability and Statistics jokes
# 56  Probability and Statistics jokes
#
#                                                 Quote  \
# 0   Hold your peace, senor," said Sancho; "faith, ...
# 1   Yes, indeed there are. Well, I will keep you i...
# 2   Oh! thank you," said Diamond. "I shall be sorr...
# 3   Twenty years from now you will be more disappo...
# 4   The world is continuous, but the mind is discr...
# 5   The most beautiful experience is the mysteriou...
# 6   I have not failed. I've just found 10,000 ways...
# 7   In theory, there is no difference between theo...
# 8   One cannot understand... the universality of l...
# 9   When I am working on a problem I never think a...
# 10  Philosophy is written in this grand book--I me...
# 11  Science is what we understand well enough to e...
# 12  Sometimes a good idea comes to you when you ar...
# 13  In mathematics you don't understand things. Yo...
# 14  Truth is ever to be found in the simplicity, a...
# 15  Thought is only a flash between two long night...
# 16  All truth passes through three stages. First, ...
# 17  Spoon feeding, in the long run teaches us noth...
# 18  One of the big misapprehensions about mathemat...
# 19  Education is the most powerful weapon which yo...
# 20  We are usually convinced more easily by reason...
# 21  If you want to build a ship, don't drum up peo...
# 22  We've taught you that the earth is round, That...
# 23  For a list of all the ways technology has fail...
# 24  Alice laughed: 'There's no use trying,' she sa...
# 25  The grand thing is to be able to reason backwa...
# 26  Have you ever observed that we pay much more a...
# 27  Once you eliminate the impossible, whatever re...
# 28  Contradiction is not a sign of falsity, nor th...
# 29  Mathematics is a collection of cheap tricks an...
# 30  Abstraction consists essentially in the creati...
# 31  Mathematics is the art of giving the same name...
# 32  First, it is neccessary to study the facts, to...
# 33  To many, mathematics is a collection of theore...
# 34  I have photographed many people: artists, writ...
# 35  Induction makes you feel guilty for getting so...
# 36  A mathematician who is not also something of a...
# 37  Suppose that we think of the integers lined up...
# 38            Analysis is the art of taming infinity.
# 39  Mathematics compares the most diverse phenomen...
# 40  The only way to learn mathematics is to do mat...
# 41  The purpose of computation is insight, not num...
# 42  I believe that mathematical reality lies outsi...
# 43  The student of mathematics has to develop a to...
# 44  I believe that numbers and functions of Analys...
# 45  The imaginary number is a fine and wonderful r...
# 46  Nature laughs at the difficulties of integration.
# 47  There is nothing as dreamy and poetic, nothing...
# 48  To speak freely of mathematics, I find it the ...
# 49  I'm a mathematical optimist: I deal only with ...
# 50  A mathematician is a blind man in a dark room ...
# 51  Bart: Hey, Houdini! Why don't you saw Martin i...
# 52  Order is not sufficient. What is required, is ...
# 53  What if everything is an illusion and nothing ...
# 54    It is not certain that everything is uncertain.
# 55  USA Today has come out with a new survey--appa...
# 56  There is something in statistics that makes it...
#
#                                           Attribution
# 0   Miguel de Cervantes, The Ingenious Gentleman D...
# 1   Friedrich Nietzsche, The Gay Science (1882, 18...
# 2     George MacDonald, At the Back of the North Wind
# 3                               Mark Twain, 1835-1910
# 4   David Mumford, ICM 2002 plenary talk, Aug. 21,...
# 5                          Albert Einstein, 1879-1955
# 6                       Thomas Alva Edison, 1847-1931
# 7                          Jan L.A. van de Snepscheut
# 8                                  Richard P. Feynman
# 9                       Buckminster Fuller, 1895-1983
# 10                         Johannes Kepler, 1571-1630
# 11  Donald E. Knuth, Foreword to A=B by Petkovsek,...
# 12  Kary Mullis, The Unusual Origin of the Polymer...
# 13                        John von Neumann, 1903-1957
# 14                            Isaac Newton, 1643-1727
# 15                    Jules Henri Poincare, 1854-1912
# 16                     Arthur Schopenhauer, 1788-1860
# 17                                      E. M. Forster
# 18                                        Leon Henkin
# 19                                     Nelson Mandela
# 20                                      Blaise Pascal
# 21                           Antoine de Saint-Exupery
# 22             Dr. Seuss, Hooray for Diffendoofer Day
# 23                                         Alice Kahn
# 24                    L. Carroll, Alice in Wonderland
# 25             Arthur Conan Doyle, A study in scarlet
# 26                                 Philip G. Hamerton
# 27  Sherlock Holmes, by Sir Arthur Conan Doyle, 18...
# 28                                      Blaise Pascal
# 29                                        Lipman Bers
# 30                                          G. Cantor
# 31                    Jules Henri Poincare, 1854-1912
# 32                   Augustin Louis Cauchy, 1789-1857
# 33  John B. Conway, Subnormal Operators, Pitman Ad...
# 34  Mariana Cook, In the preface of her book Mathe...
# 35                                       Hermann Weyl
# 36                                   Karl Weierstrass
# 37  Peter J. Eccles, An Introduction to Mathematic...
# 38  Neil Falkner, Amer. Math. Monthly 116 (2009), ...
# 39            Jean Baptiste Joseph Fourier, 1768-1830
# 40                                        Paul Halmos
# 41                        Richard Hamming, 1915--1998
# 42                               Godfrey Harold Hardy
# 43  Gila Hanna, in David Tall (ed.), Advanced math...
# 44  Charles Hermite, quoted in Morris Kline's Math...
# 45               Gottfried Wilhelm Leibniz, 1646-1716
# 46                            Pierre-Simon de Laplace
# 47            Paul Lockhart, A mathematician's lament
# 48                                      Blaise Pascal
# 49                                   Tendai Chitewere
# 50                                  Charles R. Darwin
# 51                        Matt Groening, The Simpsons
# 52                  Alfred North Whitehead, 1861-1947
# 53                                         Woody Alen
# 54                                      Blaise Pascal
# 55                                    David Letterman
# 56                                    Gian-Carlo Rota

# %%
import pandas as pd
import re

def parse_quotes_md(file_path):
    # Read the markdown file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    
    # Find section headers
    sections = re.findall(r'###\s+(.+)', content)
    
    # Create a pattern to match blockquotes with their attributions
    quote_pattern = re.compile(r'(> "[\s\S]+?(?="))\s*>[\s\S]+?\*\*--_(.+?)_\*\*', re.MULTILINE)
    
    # Find all quotes and their indices
    quotes_attributions_indices = [(match.group(1), match.group(2), match.start())
                                   for match in quote_pattern.finditer(content)]
    
    # Data to create DataFrame
    data = []
    
    # Track the current section index
    current_section = ''
    current_section_index = 0

    # Iterate through each quote and attribution pair with its index
    for quote, attribution, index in quotes_attributions_indices:
        # Find current section based on index
        while current_section_index + 1 < len(sections) and \
              content.find('### ' + sections[current_section_index + 1]) < index:
            current_section_index += 1
        current_section = sections[current_section_index]
        
        # Clean the quote string
        quote = quote.strip('> " ').replace('\n', ' ').replace('\n> ', ' ')
        
        # Append the quote, its attribution, and the current section to the data list
        data.append({'Section': current_section, 'Quote': quote, 'Attribution': attribution})
    
    # Create a DataFrame
    df = pd.DataFrame(data)
    
    # Save to CSV
    df.to_csv('quotes.csv', index=False)
    
    return df

# Parse the markdown and get the DataFrame
file_path = 'quotes.md'
df = parse_quotes_md(file_path)

# Display the DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import re

def parse_quotes_md(file_path):
    # Read the markdown file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    
    # Remove the Table of Contents for easier processing
    content = re.sub(r'# Table of Contents[\s\S]*?Back to Brandon\'s page\)', '', content)

    # Find section headers
    sections = re.findall(r'###\s+(.+?)\n', content)
    
    # Create a pattern to match blockquotes with their attributions
    # The regex below does the following:
    # - Match a greater-than sign followed by optional whitespace and a quote mark
    # - Match the quote content lazily, allowing for newlines
    # - Match the attribution pattern which starts and ends with asterisks
    quote_pattern = re.compile(
        r'>\s*"([\s\S]+?)\s*"\s*\n>\s*\n>\s*\*\*--_([\s\S]+?)_\*\*', 
        re.MULTILINE)
    
    # Initialize list to hold each quote and its details
    quotes = []
    
    # Initialize variables to keep track of the current section and its starting index in content
    current_section = ''
    section_start_index = 0
    
    # Iterate over each section to find the quotes within it
    for section in sections:
        # Find the index where the current section header is located in the content
        section_start_index = content.index(section, section_start_index) + len(section)
        
        # Determine the end index of the current section (start of next section or EOF)
        next_section_start_index = content.find('###', section_start_index)
        if next_section_start_index == -1:
            next_section_start_index = len(content)
        
        # Extract the content of the current section
        section_content = content[section_start_index:next_section_start_index]
        
        # Find all quotes within the current section
        for quote_match in quote_pattern.finditer(section_content):
            # Clean and normalize the quote and attribution
            quote = quote_match.group(1).strip().replace('\n>', '').replace('\n', ' ')
            attribution = quote_match.group(2).strip()
            
            # Append to the list of quotes
            quotes.append({'Section': section, 'Quote': quote, 'Attribution': attribution})

    # Create a DataFrame from the list of quotes
    df = pd.DataFrame(quotes)
    
    # Save to CSV
    df.to_csv('quotes.csv', index=False)
    
    return df

# Define the path to the markdown file
file_path = 'quotes.md'

# Parse the markdown file and get the DataFrame
df = parse_quotes_md(file_path)

# Display the DataFrame
print(df)
# Out:
#                              Section  \
# 0                           Nihilism
# 1                          Suffering
# 2                            Passion
# 3                         Psychology
# 4                            Science
# 5                            Science
# 6                            Science
# 7                            Science
# 8                            Science
# 9                            Science
# 10                           Science
# 11                           Science
# 12                           Science
# 13                           Science
# 14                           Science
# 15                           Science
# 16                           Science
# 17                          Teaching
# 18                          Teaching
# 19                          Teaching
# 20                          Teaching
# 21                          Teaching
# 22                          Teaching
# 23                        Technology
# 24                             Logic
# 25                             Logic
# 26                             Logic
# 27                             Logic
# 28                             Logic
# 29                              Math
# 30                              Math
# 31                              Math
# 32                              Math
# 33                              Math
# 34                              Math
# 35                              Math
# 36                              Math
# 37                              Math
# 38                              Math
# 39                              Math
# 40                              Math
# 41                              Math
# 42                              Math
# 43                              Math
# 44                              Math
# 45                              Math
# 46                              Math
# 47                              Math
# 48                              Math
# 49                        Math Jokes
# 50                        Math Jokes
# 51                        Math Jokes
# 52                        Philosophy
# 53               Philosophical jokes
# 54                       Probability
# 55  Probability and Statistics jokes
# 56  Probability and Statistics jokes
#
#                                                 Quote  \
# 0   How shall we comfort ourselves, the murderers ...
# 1   Oh! thank you," said Diamond. "I shall be sorr...
# 2   Twenty years from now you will be more disappo...
# 3   The world is continuous, but the mind is discr...
# 4   The most beautiful experience is the mysteriou...
# 5   I have not failed. I've just found 10,000 ways...
# 6   In theory, there is no difference between theo...
# 7   One cannot understand... the universality of l...
# 8   When I am working on a problem I never think a...
# 9   Philosophy is written in this grand book--I me...
# 10  Ubi materia, ibi geometria."   "Geometry is th...
# 11  Science is what we understand well enough to e...
# 12  Sometimes a good idea comes to you when you ar...
# 13  In mathematics you don't understand things. Yo...
# 14  Truth is ever to be found in the simplicity, a...
# 15  Thought is only a flash between two long night...
# 16  All truth passes through three stages. First, ...
# 17  Spoon feeding, in the long run teaches us noth...
# 18  One of the big misapprehensions about mathemat...
# 19  Education is the most powerful weapon which yo...
# 20  We are usually convinced more easily by reason...
# 21  If you want to build a ship, don't drum up peo...
# 22  We've taught you that the earth is round, That...
# 23  For a list of all the ways technology has fail...
# 24  Alice laughed: 'There's no use trying,' she sa...
# 25  The grand thing is to be able to reason backwa...
# 26  Have you ever observed that we pay much more a...
# 27  Once you eliminate the impossible, whatever re...
# 28  Contradiction is not a sign of falsity, nor th...
# 29  Quapropter bono christiano, sive mathematici, ...
# 30  Abstraction consists essentially in the creati...
# 31  Mathematics is the art of giving the same name...
# 32  First, it is neccessary to study the facts, to...
# 33  To many, mathematics is a collection of theore...
# 34  I have photographed many people: artists, writ...
# 35  Induction makes you feel guilty for getting so...
# 36  A mathematician who is not also something of a...
# 37  Suppose that we think of the integers lined up...
# 38            Analysis is the art of taming infinity.
# 39  Mathematics compares the most diverse phenomen...
# 40  The only way to learn mathematics is to do mat...
# 41  The purpose of computation is insight, not num...
# 42  I believe that mathematical reality lies outsi...
# 43  The student of mathematics has to develop a to...
# 44  I believe that numbers and functions of Analys...
# 45  The imaginary number is a fine and wonderful r...
# 46  Nature laughs at the difficulties of integration.
# 47  There is nothing as dreamy and poetic, nothing...
# 48  To speak freely of mathematics, I find it the ...
# 49  I'm a mathematical optimist: I deal only with ...
# 50  A mathematician is a blind man in a dark room ...
# 51  Bart: Hey, Houdini! Why don't you saw Martin i...
# 52  Order is not sufficient. What is required, is ...
# 53  What if everything is an illusion and nothing ...
# 54    It is not certain that everything is uncertain.
# 55  USA Today has come out with a new survey--appa...
# 56  There is something in statistics that makes it...
#
#                                           Attribution
# 0   Friedrich Nietzsche, The Gay Science (1882, 18...
# 1     George MacDonald, At the Back of the North Wind
# 2                               Mark Twain, 1835-1910
# 3   David Mumford, ICM 2002 plenary talk, Aug. 21,...
# 4                          Albert Einstein, 1879-1955
# 5                       Thomas Alva Edison, 1847-1931
# 6                          Jan L.A. van de Snepscheut
# 7                                  Richard P. Feynman
# 8                       Buckminster Fuller, 1895-1983
# 9                Galileo Galilei, Il Saggiatore, 1623
# 10                         Johannes Kepler, 1571-1630
# 11  Donald E. Knuth, Foreword to A=B by Petkovsek,...
# 12  Kary Mullis, The Unusual Origin of the Polymer...
# 13                        John von Neumann, 1903-1957
# 14                            Isaac Newton, 1643-1727
# 15                    Jules Henri Poincare, 1854-1912
# 16                     Arthur Schopenhauer, 1788-1860
# 17                                      E. M. Forster
# 18                                        Leon Henkin
# 19                                     Nelson Mandela
# 20                                      Blaise Pascal
# 21                           Antoine de Saint-Exupery
# 22             Dr. Seuss, Hooray for Diffendoofer Day
# 23                                         Alice Kahn
# 24                    L. Carroll, Alice in Wonderland
# 25             Arthur Conan Doyle, A study in scarlet
# 26                                 Philip G. Hamerton
# 27  Sherlock Holmes, by Sir Arthur Conan Doyle, 18...
# 28                                      Blaise Pascal
# 29                                        Lipman Bers
# 30                                          G. Cantor
# 31                    Jules Henri Poincare, 1854-1912
# 32                   Augustin Louis Cauchy, 1789-1857
# 33  John B. Conway, Subnormal Operators, Pitman Ad...
# 34  Mariana Cook, In the preface of her book Mathe...
# 35                                       Hermann Weyl
# 36                                   Karl Weierstrass
# 37  Peter J. Eccles, An Introduction to Mathematic...
# 38  Neil Falkner, Amer. Math. Monthly 116 (2009), ...
# 39            Jean Baptiste Joseph Fourier, 1768-1830
# 40                                        Paul Halmos
# 41                        Richard Hamming, 1915--1998
# 42                               Godfrey Harold Hardy
# 43  Gila Hanna, in David Tall (ed.), Advanced math...
# 44  Charles Hermite, quoted in Morris Kline's Math...
# 45               Gottfried Wilhelm Leibniz, 1646-1716
# 46                            Pierre-Simon de Laplace
# 47            Paul Lockhart, A mathematician's lament
# 48                                      Blaise Pascal
# 49                                   Tendai Chitewere
# 50                                  Charles R. Darwin
# 51                        Matt Groening, The Simpsons
# 52                  Alfred North Whitehead, 1861-1947
# 53                                         Woody Alen
# 54                                      Blaise Pascal
# 55                                    David Letterman
# 56                                    Gian-Carlo Rota

# %%
import pandas as pd
import re

def parse_quotes_md(file_path):
    # Read the markdown file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    
    # Remove the Table of Contents for easier processing
    content = re.sub(r'# Table of Contents[\s\S]*?Back to Brandon\'s page\)', '', content)

    # Find section headers
    sections = re.findall(r'###\s+(.+?)\n', content)
    
    # Create a pattern to match blockquotes with their attributions
    # The regex below matches lines starting with > and ending with _**
    quote_pattern = re.compile(
        r'^>\s*(.*?)\s*—\s*[_*]{2}(.*?)_*\*{2}$', 
        re.MULTILINE)
    
    # Initialize list to hold each quote and its details
    quotes = []
    
    # Initialize variables to keep track of the current section and its starting index in content
    current_section = ''
    section_start_index = 0
    
    # Iterate over each section to find the quotes within it
    for section in sections:
        # Find the index where the current section header is located in the content
        section_start_index = content.index(section, section_start_index) + len(section)
        
        # Determine the end index of the current section (start of next section or EOF)
        next_section_start_index = content.find('###', section_start_index)
        if next_section_start_index == -1:
            next_section_start_index = len(content)
        
        # Extract the content of the current section
        section_content = content[section_start_index:next_section_start_index]
        
        # Find all quotes within the current section
        for quote_match in quote_pattern.finditer(section_content):
            # Clean and normalize the quote and attribution
            quote = quote_match.group(1).strip().replace('\n>', '').replace('\n', ' ')
            attribution = quote_match.group(2).strip()
            
            # Append to the list of quotes
            quotes.append({'Section': section, 'Quote': quote, 'Attribution': attribution})

    # Create a DataFrame from the list of quotes
    df = pd.DataFrame(quotes)
    
    # Save to CSV
    df.to_csv('quotes.csv', index=False)
    
    return df

# Define the path to the markdown file
file_path = 'quotes.md'

# Parse the markdown file and get the DataFrame
df = parse_quotes_md(file_path)

# Display the DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import re

def parse_quotes_md(file_path):
    # Read the markdown file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Define the regex pattern to match sections
    section_pattern = re.compile(r'### (.+)')
    
    # Define the regex pattern to match quotes. This pattern captures text starting with ">"
    # possibly spanning multiple lines, followed by an attribution which is in bold.
    quote_pattern = re.compile(
        r'^>\s*"?(.*?)"?\s*\n?>?\s*(\*\*--_[\s\S]+?_\*\*)', 
        re.MULTILINE)
    
    quotes = []  # Initialize list to hold quotes
    
    # Split the document into sections by titles
    parts = section_pattern.split(content)
    
    # Using enumerate to skip the first split which is the header part, and then pair the title with the content
    for section_title, section_content in zip(parts[1::2], parts[2::2]):
        # Find all quotes in the section
        for quote in quote_pattern.findall(section_content):
            # Clean up the quote and the attribution
            text, attribution = quote
            text = text.replace('\n>', '').replace('\n', ' ').strip()
            attribution = attribution.strip().replace('\n', ' ')
            # Add to the list of quotes
            quotes.append({'Section': section_title.strip(), 'Quote': text, 'Attribution': attribution})
    
    # Create DataFrame from the quotes
    df = pd.DataFrame(quotes)
    
    # Save to CSV
    df.to_csv('quotes.csv', index=False)
    
    return df

# Define the path to the markdown file
file_path = 'quotes.md'

# Parse the markdown file and get the DataFrame
df = parse_quotes_md(file_path)

# Display the DataFrame
print(df)
# Out:
#                               Section Quote  \
# 0                           Academics
# 1                           Academics
# 2                           Academics
# 3                           Academics
# 4                           Academics
# ..                                ...   ...
# 149                       Uncertainty
# 150                       Probability
# 151                       Probability
# 152  Probability and Statistics jokes
# 153  Probability and Statistics jokes
#
#                                            Attribution
# 0    **--_Miguel de Cervantes, The Ingenious Gentle...
# 1           **--_Herbert Spencer, Apr 27 1820-1903._**
# 2    **--_Noam Chomsky, A Review of B. F. Skinner's...
# 3                        **--_Mark Twain, 1835-1910_**
# 4                     **--_H. L. Mencken, 1880-1956_**
# ..                                                 ...
# 149              **--_Richard P. Feynman, 1918-1988_**
# 150  **--_J. Neyman and E. S. Pearson, On the Probl...
# 151                              **--_Blaise Pascal_**
# 152                            **--_David Letterman_**
# 153                            **--_Gian-Carlo Rota_**
#
# [154 rows x 3 columns]

# %%
import pandas as pd
import re

def parse_quotes_md(file_path):
    # Read the markdown file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Define the regex pattern to match sections
    section_pattern = re.compile(r'### (.+)')
    
    # Define the regex pattern to match quotes. This pattern captures text that may span multiple lines, 
    # and is followed by an attribution in bold.
    quote_pattern = re.compile(
        r'>(?:\s*>\s*)*"?(.*?)"?\s*\n(?=\s*> \*\*--_)', 
        re.MULTILINE | re.DOTALL)
    
    # Define the regex pattern to match attributions
    attribution_pattern = re.compile(
        r'> \*\*--_(.+?)_\*\*',
        re.MULTILINE)
    
    quotes = []  # Initialize list to hold quotes
    
    # Split the document into sections by titles
    parts = section_pattern.split(content)
    
    # Iterate over the sections
    for section_title, section_content in zip(parts[1::2], parts[2::2]):
        # Find all quotes in the section
        for quote_text in quote_pattern.findall(section_content):
            # Clean up the quote text
            quote_text = quote_text.strip().replace('\n>', '').replace('\n', ' ').strip()
            # Find the corresponding attribution
            attribution_match = attribution_pattern.search(section_content)
            attribution = attribution_match.group(1).strip().replace('\n', ' ') if attribution_match else 'Unknown'
            # Add to the list of quotes
            quotes.append({'Section': section_title.strip(), 'Quote': quote_text, 'Attribution': attribution})
            # Remove the matched text to avoid capturing the same attribution multiple times
            section_content = section_content.replace(attribution_match.group(0), '', 1)
    
    # Create DataFrame from the quotes
    df = pd.DataFrame(quotes)
    
    # Save to CSV
    df.to_csv('quotes.csv', index=False)
    
    return df

# Define the path to the markdown file
file_path = 'quotes.md'

# Parse the markdown file and get the DataFrame
df = parse_quotes_md(file_path)

# Display the DataFrame
print(df)
# Out:
#                               Section  \
# 0                           Academics
# 1                           Academics
# 2                           Academics
# 3                           Academics
# 4                           Academics
# ..                                ...
# 143                       Uncertainty
# 144                       Probability
# 145                       Probability
# 146  Probability and Statistics jokes
# 147  Probability and Statistics jokes
#
#                                                  Quote  \
# 0    "Hold your peace, senor," said Sancho; "faith,...
# 1    **--_Miguel de Cervantes, The Ingenious Gentle...
# 2    **--_Herbert Spencer, Apr 27 1820-1903._**  Ev...
# 3    **--_Noam Chomsky, A Review of B. F. Skinner's...
# 4    **--_Mark Twain, 1835-1910_**  For every probl...
# ..                                                 ...
# 143  **--_Richard P. Feynman, 1918-1988_**  “I can ...
# 144  ...no test based upon a theory of probability ...
# 145  **--_J. Neyman and E. S. Pearson, On the Probl...
# 146  "USA Today has come out with a new survey--app...
# 147  **--_David Letterman_**  "There is something i...
#
#                                            Attribution
# 0    Miguel de Cervantes, The Ingenious Gentleman D...
# 1                   Herbert Spencer, Apr 27 1820-1903.
# 2    Noam Chomsky, A Review of B. F. Skinner's Verb...
# 3                                Mark Twain, 1835-1910
# 4                             H. L. Mencken, 1880-1956
# ..                                                 ...
# 143                      Richard P. Feynman, 1918-1988
# 144  J. Neyman and E. S. Pearson, On the Problem of...
# 145                                      Blaise Pascal
# 146                                    David Letterman
# 147                                    Gian-Carlo Rota
#
# [148 rows x 3 columns]
